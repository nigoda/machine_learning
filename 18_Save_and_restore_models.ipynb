# %% [markdown]
# <a href="https://colab.research.google.com/github/nigoda/machine_learning/blob/main/18_Save_and_restore_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install h5py pyyaml

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import os

# !pip install tensorflow==2.0.0-beta1
import tensorflow as tf 
from tensorflow import keras

tf.__version__
# Out:
# ...
#      |████████████████████████████████| 88.7MB 44kB/s
# ...
#      |████████████████████████████████| 3.1MB 44.7MB/s
# ...
#      |████████████████████████████████| 501kB 40.0MB/s
# ...
#      |████████████████████████████████| 51kB 6.7MB/s
# ...
#   Found existing installation: tensorflow 2.4.1
#     Uninstalling tensorflow-2.4.1:
#       Successfully uninstalled tensorflow-2.4.1
# ...
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# ...

# %%
(train_images, train_labels),(test_images, test_labels) = tf.keras.datasets.mnist.load_data()

train_labels = train_labels[:1000]
test_labels = test_labels[:1000]

train_images = train_images[:1000].reshape(-1, 28*28) / 255.0
test_images = test_images[:1000].reshape(-1,28*28) / 255.0
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
print(train_labels)
# Out:
# [5 0 4 1 9 2 1 3 1 4 3 5 3 6 1 7 2 8 6 9 4 0 9 1 1 2 4 3 2 7 3 8 6 9 0 5 6
#  0 7 6 1 8 7 9 3 9 8 5 9 3 3 0 7 4 9 8 0 9 4 1 4 4 6 0 4 5 6 1 0 0 1 7 1 6
#  3 0 2 1 1 7 9 0 2 6 7 8 3 9 0 4 6 7 4 6 8 0 7 8 3 1 5 7 1 7 1 1 6 3 0 2 9
#  3 1 1 0 4 9 2 0 0 2 0 2 7 1 8 6 4 1 6 3 4 5 9 1 3 3 8 5 4 7 7 4 2 8 5 8 6
#  7 3 4 6 1 9 9 6 0 3 7 2 8 2 9 4 4 6 4 9 7 0 9 2 9 5 1 5 9 1 2 3 2 3 5 9 1
#  7 6 2 8 2 2 5 0 7 4 9 7 8 3 2 1 1 8 3 6 1 0 3 1 0 0 1 7 2 7 3 0 4 6 5 2 6
#  4 7 1 8 9 9 3 0 7 1 0 2 0 3 5 4 6 5 8 6 3 7 5 8 0 9 1 0 3 1 2 2 3 3 6 4 7
#  5 0 6 2 7 9 8 5 9 2 1 1 4 4 5 6 4 1 2 5 3 9 3 9 0 5 9 6 5 7 4 1 3 4 0 4 8
#  0 4 3 6 8 7 6 0 9 7 5 7 2 1 1 6 8 9 4 1 5 2 2 9 0 3 9 6 7 2 0 3 5 4 3 6 5
#  8 9 5 4 7 4 2 7 3 4 8 9 1 9 2 8 7 9 1 8 7 4 1 3 1 1 0 2 3 9 4 9 2 1 6 8 4
#  7 7 4 4 9 2 5 7 2 4 4 2 1 9 7 2 8 7 6 9 2 2 3 8 1 6 5 1 1 0 2 6 4 5 8 3 1
#  5 1 9 2 7 4 4 4 8 1 5 8 9 5 6 7 9 9 3 7 0 9 0 6 6 2 3 9 0 7 5 4 8 0 9 4 1
# ...

# %%
# Return a short sequential model
def create_model():

  model = tf.keras.models.Sequential([
      keras.layers.Dense(512, activation='relu', input_shape=(784,)),
      keras.layers.Dropout(0.2),
      keras.layers.Dense(10, activation='softmax')
  ])

  model.compile(optimizer='adam',
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  return model

   #Create a basic model instance
model = create_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 512)               401920
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# ...
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## **Save checkpoints during training**
#
# The primary use is to automatically save checkpoints during and at the end of training. This way you can use a trained model without having to retrain it, or pick-up training where you left of-in case the training process was interrupted
#
# `tf.keras.callbacks.ModelCheckpoint` is a callback that performs this task. The callback takes a couple of arguments to configure checkpointing.
#
# ### **Checkpoint callback usage**
#
# Train the model and pass it the ModelCheckpoint callback:

# %%
checkpoint_path = "training/cd.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create checkpoint callback
cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,
                                                save_weight_only=True,
                                                verbose=1)

model = create_model()
model.save_weights(checkpoint_path)
model.fit(train_images, train_labels, epochs=10,
          validation_data = (test_images, test_labels),
          callbacks = [cp_callback]) # pass call back training



# This may generate warnings related to saving the states of the optimizer.
# These warnings (and similar warining throughout this notebook) are in place to discourage outdated usage, and can be ignored.
# Out:
# Train on 1000 samples, validate on 1000 samples
# Epoch 1/10
#  768/1000 [======================>.......] - ETA: 0s - loss: 1.2714 - accuracy: 0.6562
# Epoch 00001: saving model to training/cd.ckpt
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7f3e60015c20> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7f3e60015c20>: AttributeError: module 'gast' has no attribute 'Num'
# ...

# %% [markdown]
# This creates a single collection of TensorFlow checkpoint files that are updated at the end of each epoch:

# %%
# !ls {checkpoint_dir}
# Out:
# cd.ckpt  cd.ckpt.data-00000-of-00001  cd.ckpt.index  checkpoint

# %% [markdown]
# Create a new, untrained model. when restoring a model from only weight, you must have a model with the same architecture as the orginal model.
# Since it's the same model architecutre, we can share weights despite that it's a different instance of the model.
#
# Now rebuild a fresh, untrained model, and evaluate it on the test set. An untrained model will perform at chance levels(≈10% accuracy):

# %%
model = create_model()

loss, acc = model.evaluate(test_images, test_labels)
print("Untrained model, accuracy: {:5.2f}%".format(100*acc))
# Out:
# 1000/1000 [==============================] - 0s 88us/sample - loss: 2.3507 - accuracy: 0.1140
# Untrained model, accuracy: 11.40%

# %% [markdown]
# Then load the weight from the checkpoint, and re-evaluate:

# %%
model.load_weights(checkpoint_path)
loss, acc = model.evaluate(test_images,test_labels)
print("Restored model, accuracy: {:5.2f}%".format(100*acc))
# Out:
# 1000/1000 [==============================] - 0s 66us/sample - loss: 2.2621 - accuracy: 0.1580
# Restored model, accuracy: 15.80%

# %% [markdown]
# ### **Checkpoint callback option**
#
# The callback provides several options to give the resulting unique names, and adjust the checkpoint frequency.
#
# Train a new model, and save uniquely named chechpoints once every 5-epochs:

# %%
# include the epoch in the file name. (uses 'str.format')
checkpoint_path = "training_2/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

cp_callback = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_path, verbose=1, save_weights_only=True,
    period=5)

model = create_model()
model.save_weights(checkpoint_path.format(epoch=0))
model.fit(train_images, train_labels,
          epochs=50, callbacks = [cp_callback],
          validation_data = (test_images, test_labels),
          verbose=0)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00030: saving model to training_2/cp-0030.ckpt
#
# Epoch 00035: saving model to training_2/cp-0035.ckpt
#
# Epoch 00040: saving model to training_2/cp-0040.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt

# %%
! ls {checkpoint_dir}
# Out:
# checkpoint			  cp-0025.ckpt.index
# cp-0000.ckpt.data-00000-of-00001  cp-0030.ckpt.data-00000-of-00001
# cp-0000.ckpt.index		  cp-0030.ckpt.index
# cp-0005.ckpt.data-00000-of-00001  cp-0035.ckpt.data-00000-of-00001
# cp-0005.ckpt.index		  cp-0035.ckpt.index
# cp-0010.ckpt.data-00000-of-00001  cp-0040.ckpt.data-00000-of-00001
# cp-0010.ckpt.index		  cp-0040.ckpt.index
# cp-0015.ckpt.data-00000-of-00001  cp-0045.ckpt.data-00000-of-00001
# cp-0015.ckpt.index		  cp-0045.ckpt.index
# cp-0020.ckpt.data-00000-of-00001  cp-0050.ckpt.data-00000-of-00001
# cp-0020.ckpt.index		  cp-0050.ckpt.index
# cp-0025.ckpt.data-00000-of-00001

# %%
latest = tf.train.latest_checkpoint(checkpoint_dir)
latest
# Out:
# 'training_2/cp-0050.ckpt'

# %%
model = create_model()
model.load_weights(latest)
loss, acc = model.evaluate(test_images, test_labels)
print("Restored model, accuracy : {:5.2f}%".format(100*acc))
# Out:
# 1000/1000 [==============================] - 0s 92us/sample - loss: 0.5083 - accuracy: 0.8790
# Restored model, accuracy : 87.90%

# %% [markdown]
# ### **What are these files?**
#
# The above code stores the weights to a collection of `checkpoint-`formatted files that contain only the trained weights in a binary formate.
#
# Checkpoints contain:
#
#
# *   One or more shards that contain your model's weights.
# *   An index file that indicates which weights are stored in a which shard.
#
# if you are only training a model on a single machine, you'll have one shard with the suffix: `.data-00000-of-00001`

# %% [markdown]
# ### **Manually save weights**
#
# Above you saw how to load the weights into model.
#
# Manually saving the weights is just as simple, use the `Model.save_weights` method,

# %%
# Save the weights
model.save_weights('./checkpoints/my_checkpoint')

# Restore the weights
model = create_model()
model.load_weights('./checkpoints/my_checkpoint')

loss, acc = model.evaluate(test_images, test_labels)
print("Restore model, accuracy :{:5.2f}%".format(100*acc))
# Out:
# 1000/1000 [==============================] - 0s 86us/sample - loss: 0.5083 - accuracy: 0.8790
# Restore model, accuracy :87.90%

# %% [markdown]
# ## **Save the entire model**
#
# The model and optimizer can be saved to a file that contains both their states(weights and variables), and the model configuration. This allows you to export a model so it can be used without access to the original python code. Since the optimizer-state is recovered you can evenr resume training from exactly where you left off.
#
# Saving a fully-funtion model is very useful-you can load them in TenorFlow.js(HDF5,Save Model) and then train and run them in web browsers, or convert them to run on mobile device using TensorFlow lite(HDF5, Save Model)

# %% [markdown]
# ### **As an HDF5 FILE**
# Keras provides a basic save formate using HDF5 standard. For our purposes,the saved model can br treated as a sinlge binary blob.

# %%
model = create_model()

model.fit(train_images, train_labels,epochs=5)

# Save entire model to a HDF5 file
model.save('my_model.h5')
# Out:
# Train on 1000 samples
# Epoch 1/5
# 1000/1000 [==============================] - 0s 212us/sample - loss: 1.0683 - accuracy: 0.7170
# Epoch 2/5
# 1000/1000 [==============================] - 0s 133us/sample - loss: 0.3755 - accuracy: 0.8940
# Epoch 3/5
# 1000/1000 [==============================] - 0s 155us/sample - loss: 0.2436 - accuracy: 0.9360
# Epoch 4/5
# 1000/1000 [==============================] - 0s 136us/sample - loss: 0.1775 - accuracy: 0.9620
# Epoch 5/5
# 1000/1000 [==============================] - 0s 158us/sample - loss: 0.1197 - accuracy: 0.9760

# %% [markdown]
# Now recreate the model from that file:

# %%
# Recreate the exact same model, including weights and optimizer.
new_model = keras.models.load_model('my_model.h5')
new_model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_16 (Dense)             (None, 512)               401920
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 10)                5130
# ...
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Check the accuracy:
loss, acc = new_model.evaluate(test_images, test_labels)
print("Restored model, accuracy: {:5.2f}%".format(100*acc))
# Out:
# 1000/1000 [==============================] - 0s 85us/sample - loss: 0.4278 - accuracy: 0.8640
# Restored model, accuracy: 86.40%

# %% [markdown]
# This techiniue saves everthing:
#
#
# *   The weight values
# *   The model's configuration(architecture)
# *   The optimizer configuration
#
# Keras saved models by inspecture the architecture>

# %%
print(type("dgf"))

age = isinstance("af",str)
print(age)
# Out:
# <class 'str'>
# True
